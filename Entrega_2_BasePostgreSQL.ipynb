# %%
# import librerias 
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Se establece conexion a PostgreSQL gracias a la libreria psycopg2
conn_string = 'postgresql+psycopg2://postgres:Leo1993+@127.0.0.1/Prueba'
  
db = create_engine(conn_string)
conn = db.connect()
conn1 = psycopg2.connect(
                        database="Gestion2",
                        user='postgres', 
                        password='Leo1993+', 
                        host='127.0.0.1', 
                        port= '5432'
)

conn1.autocommit = True
cursor = conn1.cursor()
  
# Acontinuacion se crean las tablas relacionadas definidas en python creadas en PgAdmin 
cursor.execute('drop table if exists airlines_final')
  
sql = '''CREATE TABLE artistas(      id VARCHAR(255),
                                     followers FLOAT,
                                     name VARCHAR(255),
                                      popularity INTEGER);
                                     
         CREATE TABLE generos(       id SERIAL,
                                     name VARCHAR(255),
                                     genres FLOAT);
            
         CREATE TABLE canciones(     id VARCHAR(255),
                                     name VARCHAR(255),
                                     popularity FLOAT,
                                     duration_ms INTEGER,
                                     explicit INTEGER,
                                     id_artists VARCHAR(255),
                                     release_date DATE,
                                     danceability FLOAT,
                                     energy FLOAT,
                                     key FLOAT,
                                     loudness FLOAT,
                                     mode FLOAT,
                                     speechiness FLOAT,
                                     acousticness FLOAT,
                                     instrumentalness FLOAT,
                                     liveness FLOAT,
                                     valence FLOAT,
                                     tempo FLOAT,
                                     time_signature FLOAT
                                     );
                                     

       '''
  
cursor.execute(sql)
  
# Se importan los rchivos "artists_mod" y "tracks_mod" con los cuales se crearan las tablas relacionadas. 
artists_mod = pd.read_csv("artists_mod.csv") 
tracks_mod =  pd.read_csv("tracks_mod.csv")
  
data1 = artists_mod[["id","followers","name","popularity"]]
data2 = artists_mod[["id","name","genres"]]
data3 = tracks_mod[["id","name","popularity","duration_ms","explicit","id_artists","release_date",
                   "danceability","energy","key","loudness","mode","speechiness",
                   "acousticness","instrumentalness","liveness","valence","tempo","time_signature"]]

# Se visualizan los DataFrame creados con los cuales se alimentan las tablas realacionadas 
print(data1)
print(data2)
print(data3)
  
# Se convierte la informacion Data frame a SQL 
data1.to_sql('artistas', conn, if_exists= 'replace')
data2.to_sql('generos', conn, if_exists= 'replace')
data3.to_sql('canciones', conn, if_exists= 'replace')
  
# Se recorren las tablas, y se imprimen para verificar un adecuado guardado de informacion. 
sql1='''select * from artistas;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)
  
conn1.commit()
conn1.close()
# Out:
#                              id  followers  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0
# 1        0DlhY15l3wsrnlfGio2bjU        5.0
# 2        0DmRESX2JknGPQyO15yxg7        0.0
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0
# ...                         ...        ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# 2                                                 Sadaa           0
# 3                                             Tra'gruda           0
# 4                                Ioannis Panoutsopoulos           0
# ...
